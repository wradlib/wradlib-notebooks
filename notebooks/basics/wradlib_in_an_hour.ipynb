# %% [markdown]
# This notebook is part of the $\omega radlib$ documentation: https://docs.wradlib.org.
#
# Copyright (c) $\omega radlib$ developers.
# Distributed under the MIT License. See LICENSE.txt for more info.

# %% [markdown]
# # A one hour tour of wradlib
#
# ![caption](../files/cover_image.png)

# %% [markdown]
# A guided tour of some $\omega radlib$ notebooks.

# %% [markdown]
# ## Some background, first

# %% [markdown]
# Development started in 2011...or more precisely:
#
# `October 26th, 2011`

# %% [markdown]
# ### Key motivation
#
# `A community platform for collaborative development of algorithms`

# %% [markdown]
# ## Your entry points

# %% [markdown]
# ### Start out from [wradlib.org](https://wradlib.org)

# %% [markdown]
# ### Documentation
#
# Check out the [online docs](https://docs.wradlib.org/) with tutorials and examples and a comprehensive [library reference](https://docs.wradlib.org/en/latest/reference.html)

# %% [markdown]
# ### Openradar discourse
#
# Get help and connect with weather radar enthusiasts from all over the world at [openradar-discourse](https://openradar.discourse.group)!

# %% [markdown]
# ## For developers
#
# See our [contributing guide](https://docs.wradlib.org/en/latest/dev_guide.html).

# %% [markdown]
# ## Installation
#
# See [Installation-Section](https://docs.wradlib.org/en/latest/installation.html).

# %% [markdown]
# ## To run our tutorials

# %% [markdown]
# 1. Get [notebooks](https://github.com/wradlib/wradlib-notebooks)
# 2. Get [sample data](https://github.com/wradlib/wradlib-data)
# 3. Set environment variable `WRADLIB_DATA`
#
# See also: https://docs.wradlib.org/en/latest/jupyter.html

# %% [markdown]
# ## Development paradigm

# %% [markdown]
# ### Keep the magic to a minimum

# %% [markdown]
# - transparent
# - flexible, but lower level

# %% [markdown]
# ### Flat (or no) data model

# %% [markdown]
# - pass data as numpy arrays,
# - and pass metadata as dictionaries.

# %% [markdown]
# ### Labelled multi-dimensional arrays

# %% [markdown]
# - combine data, coordinates and attributes in flexible structures with [xarray](https://docs.xarray.dev/en/stable/) and [xradar](https://docs.openradarscience.org/projects/xradar/en/stable/)
# - transparent multiprocessing using [dask](https://docs.dask.org/en/stable/)

# %% [markdown]
# ## Import wradlib

# %%
import wradlib

# %%
# check installed version
print(wradlib.__version__)
# Out:
# 2.1.0

# %% [markdown]
# In the next cell, type `wradlib.` and hit `Tab`.
#
# *Inpect the available modules and functions.*

# %% [markdown]
# ## Reading and viewing data

# %% [markdown]
# ### Read and quick-view
# Let's see how we can [read and quick-view a radar scan](../visualisation/plot_ppi.ipynb).

# %% [markdown]
# ### Zoo of file formats
# This notebook shows you how to [access various file formats](../fileio.ipynb).

# %% [markdown]
# ## Addressing observational errors and artefacts

# %% [markdown]
# ### Attenuation
#
# In [this example](../attenuation/attenuation.ipynb), we reconstruct path-integrated attenuation from single-pol data of the German Weather Service.

# %% [markdown]
# ### Clutter detection
#
# wradlib provides several methods for clutter detection. [Here](../classify/fuzzy_echo.ipynb), we look at an example that uses dual-pol moments and a simple fuzzy classification.

# %% [markdown]
# ### Partial beam blockage
#
# In [this example](../beamblockage/beamblockage.ipynb), wradlib attempts to quantify terrain-induced beam blockage from a DEM.

# %% [markdown]
# ## Integration with other geodata

# %% [markdown]
# ### Average precipitation over your river catchment
#
# In this example, we [compute zonal statistics](../zonalstats/zonalstats_quickstart.ipynb) over polygons imported in a shapefile.

# %% [markdown]
# ### Over and underlay of other geodata
#
# Often, you need to [present your radar data in context with other geodata](../visualisation/gis_overlay.ipynb) (DEM, rivers, gauges, catchments, ...).

# %% [markdown]
# ## Merging with other sensors

# %% [markdown]
# ### Adjusting radar-based rainfall estimates by rain gauges
#
# In [this example](../multisensor/gauge_adjustment.ipynb), we use synthetic radar and rain gauge observations and confront them with different adjustment techniques.
